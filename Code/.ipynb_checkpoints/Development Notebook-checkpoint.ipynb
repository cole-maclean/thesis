# %% [markdown]
# <h1>Thesis</h1>
# <h2>Intro to Complex Networks and Random Graphs</h2>
# <h2>Intro to RGGs and Related Models</h2>
# <h2>Model Discription</h2>
# <h2>Connectivity Threshold</h2>
# <h2>Other Network Properties</h2>
# <h2>Applied Study - Tesla Supercharger Network</h2>
# <h2>Conclusions and Future Work</h2>

# %%
#Imports
import cProfile
import random
import math
import geohash
import geotools
import networkx as nx
import numpy as np
from scipy import spatial,stats


from joblib import Parallel, delayed

# %% [markdown]
# <h2>Geographic Sims</h2>

# %%
def generate_nodes(N,pop_min_max,lat_min_max,lon_min_max):
    '''Generate a normally random dictionary of N geographic nodes with data dictionary of node population and lat/lon coords
    N = numer of nodes
    pop_min_max = tuple of [min,max] population thresholds
    lat_min_max = tuple of [min,max] latitude thresholds
    lon_min_max = tuple of [min,max] longitude thresholds
    '''
    
    node_dict = {}
    for node in range(N):
        lat = random.uniform(*lat_min_max)
        lon = random.uniform(*lon_min_max)
        gh = geohash.encode(lat,lon)
        node_dict[gh] = {'pop':random.randint(*pop_min_max),
                           'lat':lat,
                           'lon':lon,
                           'geohash':gh
                          }
    return node_dict

def generate_network(node_dict,max_connect_dist,link_prob):
    seen_edges = []
    G = nx.Graph()
    for node,data in node_dict.items():
        if node not in G.nodes():
            G.add_node(node,attr_dict=data)
        possible_connections = geotools.get_close_ghs(data['geohash'],G.nodes(),max_connect_dist)
        for connection_node in possible_connections:
            edge_hash = ''.join(sorted([node,connection_node]))
            if random.random() <= link_prob and edge_hash not in seen_edges:
                G.add_edge(node,connection_node)
            seen_edges.append(edge_hash)
    return G

# %%
node_dict = generate_nodes(10,[10,100],[30.,70],[40,50])
G = generate_network(node_dict,0.1,0.1)
# Out:
# tj89vxxhz4ggtj89vxxhz4gg

# %%
nx.draw_networkx(G)

# %% [markdown]
# <h2>Random Geometric Graphs</h2>

# %%
def generate_graph_nodes(N,dimensions=2):
    G = nx.Graph()
    for node in range(N):
        pos = [random.random() for dim in range(dimensions)]
        G.add_node(node,pos=pos,weight=random.expovariate(1.0))
    return G

def dynamic_GTG(G,max_distance,alpha,beta,gamma):
    pos_points = list(nx.get_node_attributes(G, 'pos').values())
    point_tree = spatial.cKDTree(pos_points)
    potential_edges = point_tree.query_pairs(max_distance, len(pos_points[0]))
    for edge in potential_edges:
        dist = spatial.distance.euclidean(G.node[edge[0]]['pos'],G.node[edge[1]]['pos'])
        link_value = dist**-alpha
        link_strength = (G.node[edge[0]]['weight']+G.node[edge[1]]['weight'])*link_value
        if link_strength >= (beta*len(G))/(gamma*len(G.edges())+1):
            G.add_edge(edge[0],edge[1],weight=link_strength)                         
    return G

def integrate_threshold(N,beta,gamma):
    if gamma == 0:
        return N*beta
    else:
        return (beta*math.log(N*gamma+1))/gamma

def visualize_GTG(GTG):
    """
    Filename: nx_demo.py
    Authors: John Stachurski and Thomas J. Sargent
    """
    pos = nx.get_node_attributes(GTG, 'pos')    # Get positions of nodes
    plt.figure(figsize=(8,8))
    nx.draw_networkx_edges(GTG, pos, alpha=0.4)
    nx.draw_networkx_nodes(GTG, pos, nodelist=list(GTG.nodes()),
                           node_size=120, alpha=0.5,node_color='blue')
    plt.show()

# %%
N=100
max_distance = 0.1
test_G = generate_graph_nodes(N)
frz_pos = nx.get_node_attributes(test_G, 'pos')
frz_weight = nx.get_node_attributes(test_G, 'weight') 
test_RGG = nx.generators.geometric.random_geometric_graph(N, max_distance, dim=2, pos=frz_pos)
visualize_GTG(test_RGG)

# %%
test_DGTG = dynamic_GTG(test_G.copy(),max_distance,alpha=2,beta=0,gamma=0)
visualize_GTG(test_DGTG)

# %%
test_GTG = nx.generators.geometric.geographical_threshold_graph(N,100,pos=frz_pos,weight=frz_weight)
visualize_GTG(test_GTG)

# %%
test_DGG = dynamic_GTG(test_G.copy(),1,alpha=2,beta=100,gamma=0)
visualize_GTG(test_DGG)

# %%
N=1000
beta = 100
gamma = 0.1
test_DGG = dynamic_GTG(test_G.copy(),1,alpha=2,beta=beta,gamma=gamma)
biggest_comp = max(nx.connected_component_subgraphs(test_DGG), key=len)
AUC = integrate_threshold(N,beta,gamma)
print(len(biggest_comp)/N)
print(AUC)
visualize_GTG(test_DGG)
# Out:
# 0.02
# 2397.8952727983706

# %%
biggest_comp = max(nx.connected_component_subgraphs(test_DGG), key=len)

# %%
len(biggest_comp)/100
# Out:
# 0.02

# %%
AUC = integrate_threshold(100,100,0.15)
AUC
# Out:
# 184839.24814931874

# %% [markdown]
# <h1>Simulations</h1>

# %%
import NetSim
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import math
import collections
# %matplotlib inline

# %%
G = NetSim.generate_graph_nodes(100)

# %%
GTG= NetSim.build_GTG(G.copy(),0.1,0.001)
NetSim.visualize_GTG(GTG)

# %%
sim_data = NetSim.run_sim(N_list=[2**11,2**12],iterations=1000,
                                        max_distance_limits=[0.0,1/(math.pi**0.5)],
                                        theta_limits=[0.0,0.01],
                                        n_jobs=6)
df = pd.DataFrame(sim_data,columns=['N','K','mu','connectivity','max_distance','theta','first_comp','second_comp'])

# %%
df.to_json('sim_data_static_model.json')

# %%
df.tail(10)
# Out:
#         N       K        mu  connectivity  max_distance     theta  first_comp  \
# 190  1024  213423  0.985273    416.841797      0.487874  0.000627    1.000000
# 191  2048    6241  0.973050      6.094727      0.035149  0.000417    0.987305
# 192  1024     119  0.962349      0.232422      0.008740  0.000649    0.003906
# 193  2048  169701  0.973870    165.723633      0.250593  0.000775    1.000000
# 194  1024   53952  1.033522    105.375000      0.213024  0.000699    1.000000
# 195  2048  239065  0.998981    233.461914      0.296267  0.000765    1.000000
# 196  1024  202849  1.012137    396.189453      0.516795  0.000856    1.000000
# 197  2048   10806  1.005218     10.552734      0.041323  0.000039    1.000000
# 198  1024    3072  0.966302      6.000000      0.051716  0.000929    0.996094
# 199  2048  337385  0.974285    329.477539      0.372764  0.000749    1.000000
#
#      second_comp
# 190     0.000000
# 191     0.003418
# 192     0.003906
# 193     0.000000
# 194     0.000000
# ...

# %%
GC = sns.lmplot("connectivity", "first_comp", data=df, hue='N', fit_reg=False)
GC.set(xlim=(0, 15))

# %%
sns.lmplot("max_distance", "connectivity", data=df, hue='N', fit_reg=False)

# %%
TH = sns.lmplot("theta", "connectivity", data=df, hue='N', fit_reg=False)

# %%
df['model'] = 2*math.e**(-df['theta'])*(df['N']*math.pi*df['max_distance']**2 + df['theta'])
sns.lmplot("connectivity", "model", data=df, hue='N', fit_reg=False)

# %% [markdown]
# <h2>Dynamic Model</h2>

# %%
df = pd.read_json('sim_data.json')
df['norm_AUC'] = df['AUC']/df['N']
df['density'] = df['N']/df['max_distance']**2
d_bins = [0.0,0.025,0.05,0.075,0.1]
d_bin_labels = ['0.0','0.025','0.05','0.075']
df['max_distance_bin'] = pd.cut(df['max_distance'], d_bins, labels=d_bin_labels)
AUC_bins = [0.0,0.5,1.0,1.5,100.0]
AUC_bin_labels = ['0.0','0.5','1.0','1.5']
df['AUC_bin'] = pd.cut(df['norm_AUC'], AUC_bins, labels=AUC_bin_labels)
df.tail()
# Out:
#             AUC     N  big_comp  connectivity  max_distance        mu  \
# 995  112.080588  2048  0.002930      0.562500      0.009248  2.061951
# 996  966.550895  1024  0.005859      0.615234      0.013950  1.975714
# 997  500.682120  2048  1.000000     48.490234      0.091975  2.047808
# 998   51.621024  1024  0.053711      2.398438      0.027657  1.881875
# 999  129.716012  2048  0.025391      2.218750      0.018439  1.970557
#
#      second_big_comp  norm_AUC       density max_distance_bin AUC_bin
# 995         0.002930  0.054727  2.394698e+07              0.0     0.0
# 996         0.004883  0.943897  5.261751e+06              0.0     0.5
# 997         0.000000  0.244474  2.420976e+05            0.075     0.0
# 998         0.039062  0.050411  1.338744e+06            0.025     0.0
# 999         0.015137  0.063338  6.023340e+06              0.0     0.0

# %% [markdown]
# <h2>Giant comp vs Connectivity</h2>

# %%
GC = sns.lmplot("connectivity", "big_comp", data=df, hue='N', fit_reg=False)
GC.set(xlim=(0, 10))

# %% [markdown]
# <h2>Connectivity vs Max Distance</h2>

# %%
df['norm_connectivity'] = df['connectivity']/(df['N'])
df['norm_max_distance'] = df['max_distance']/df['N']
sns.lmplot("max_distance", "norm_connectivity", data=df, hue='AUC_bin', fit_reg=False)

# %%
def RGG_estimator(rw):
    return max(0,(math.pi)*rw['max_distance']**2)
df['rgg_estimator'] = df.apply(lambda rw: RGG_estimator (rw),axis=1)
est = sns.lmplot("max_distance", "rgg_estimator", data=df, hue='AUC_bin', fit_reg=False)

# %%
def corrected_estimator(rw):
    corrected_radius = rw['mu']*rw['max_distance']-rw['AUC']/(rw['N'])
    if corrected_radius >=0:
        return math.pi*(corrected_radius)**2
    else:
        return 0
df['corrected_estimator'] = df.apply(lambda rw: corrected_estimator (rw),axis=1)
est = sns.lmplot("max_distance", "corrected_estimator", data=df, hue='AUC_bin', fit_reg=False)

# %%
rgg_r2_error = sum((df['rgg_estimator']-df['norm_connectivity'])**2)
corrected_r2_error = sum((df['corrected_estimator']-df['norm_connectivity'])**2)
print(rgg_r2_error)
print(corrected_r2_error)
# Out:
# 3.880507766e-05
# 2.40321747828e-05

# %% [markdown]
# <h2>Giant Comp vs Max Distance</h2>

# %%
sns.lmplot("max_distance", "first_comp",col='AUC_bin',hue='N', data=df,fit_reg=False,col_wrap=2, size=5)

# %%
cProfile.run('NetSim.simulation(2000,0.05,2,1,0)')
# Out:
#          282782928 function calls (282625874 primitive calls) in 159.025 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <decorator-gen-156>:1(connected_components)
#         1    0.000    0.000    0.000    0.000 <decorator-gen-158>:1(connected_component_subgraphs)
#         1    0.010    0.010  159.025  159.025 <string>:1(<module>)
#      2000    0.001    0.000    0.002    0.000 NetSim.py:12(<listcomp>)
#         1    6.939    6.939  158.861  158.861 NetSim.py:16(dynamic_GTG)
#         1    0.000    0.000    0.000    0.000 NetSim.py:28(integrate_threshold)
#         1    0.011    0.011  159.015  159.015 NetSim.py:53(simulation)
#         1    0.003    0.003    0.008    0.008 NetSim.py:9(generate_graph_nodes)
#         1    0.000    0.000    0.000    0.000 _methods.py:25(_amax)
#         1    0.000    0.000    0.000    0.000 _methods.py:28(_amin)
# ...

# %% [markdown]
# <h2>GeoNetwork Metrics</h2>

# %%
def coverage(G,radius,resolution=100):
    half_length = math.floor(radius/(math.sqrt(2)*2))
    grid = np.zeros([resolution,resolution])
    for node,data in G.nodes_iter(data=True):
        top_left = [math.floor(data['pos'][0]*resolution)-half_length,math.floor(data['pos'][1]*resolution)-half_length]
        for x in range(half_length*2):
            for y in range(half_length*2):
                if top_left[0]+x <= resolution-1 and top_left[1] + y <=resolution-1:
                    grid[top_left[0]+x,top_left[1] + y] = 1
    return np.count_nonzero(grid)/resolution**2

# %%
def network_profiling(G,radius):
    profile = {0:[0]}
    for N in range(1,len(G)+1):
        profile[N] = []
        sub_graph = G.subgraph(list(profile.keys()))
        biggest_comp = max(nx.connected_component_subgraphs(sub_graph), key=len)
        profile[N].append(coverage(biggest_comp,radius))
    return profile

# %%
G=generate_graph_nodes(100)
GTG = distance_weighted_GTG(G.copy(),0.125,0.5,funct='exponential',funct_params=[2])
net_profile = network_profiling(GTG,20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3e5834dff7e2> in <module>()
#       1 G=generate_graph_nodes(100)
#       2 GTG = distance_weighted_GTG(G.copy(),0.125,0.5,funct='exponential',funct_params=[2])
# ----> 3 net_profile = network_profiling(GTG,20)
#
# NameError: name 'network_profiling' is not defined

# %%
def profile_GTG(N):
    G=generate_graph_nodes(N)
    return distance_weighted_GTG(G,0.125,0.2,funct='unit')
